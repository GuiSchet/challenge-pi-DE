# %%
from sqlalchemy import create_engine, text

# Cadena de conexión a sqlserver container.
engine = create_engine('mssql+pyodbc://SA:YourStrong!Passw0rd@localhost:1433/master?driver=ODBC+Driver+18+for+SQL+Server&TrustServerCertificate=yes')

# Funcion para ver las tablas creadas en el db.
def ver_tablas(engine, db_name):
    try:
        with engine.connect() as connection:
            connection.execute(f"USE {db_name}")
            result = connection.execute("SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES")
            print(f"Tablas en la base de datos '{db_name}':")
            for row in result:
                print(row.TABLE_NAME)
    except Exception as e:
        print(f"Error al obtener las tablas de la base de datos '{db_name}': {e}")

# Funcion para imprimir la tabla.
def imprimir_tabla(engine, db_name, table_name):
    try:
        with engine.connect() as connection:
            connection.execute(f"USE {db_name}")
            result = connection.execute(f"SELECT * FROM {table_name}")
            print(f"Resultados de la consulta 'SELECT *' en la tabla '{table_name}' de la base de datos '{db_name}':")
            for row in result:
                print(row)
    except Exception as e:
        print(f"Error al ejecutar la consulta. '{db_name}': {e}")

database_name = 'YourDataBase'
table_name = 'unificado'

# Ver tablas en la base de datos
ver_tablas(engine, database_name)

# Imprimir resultados de la tabla específica
imprimir_tabla(engine, database_name, table_name)
# Out:
# Tablas en la base de datos 'YourDataBase':
# Unificado
# Resultados de la consulta 'SELECT *' en la tabla 'unificado' de la base de datos 'YourDataBase':
# ('CHR18', '23614644', 'S18_23614644', 'T', 'G', '55.9749', 'PASS', 'AF=0;AO=0;DP=44;FAO=0;FDP=44;FDVR=10;FR=.;FRO=44;FSAF=0;FSAR=0;FSRF=21;FSRR=23;FWDB=-0.022169;FXX=0;HRUN=1;HS_ONLY=0;LEN=1;MLLD=257.285;OALT=G;OID=S1 ... (49 characters truncated) ... P=.;QD=5.08863;RBI=0.0836526;REFB=-0.000178046;REVB=-0.0806616;RO=44;SAF=0;SAR=0;SRF=21;SRR=23;SSEN=0;SSEP=0;SSSB=0;STB=0.5;STBP=1;TYPE=snp;VARB=0;HS', 'GT:GQ:DP:FDP:RO:FRO:AO:FAO:AF:SAR:SAF:SRF:SRR:FSAR:FSAF:FSRF:FSRR', '16582387', '0/0:55:44:44:44:44:0:0:0:0:0:21:23:0:0:21:23', 'TSVC_variants_IonCode_0106', datetime.datetime(2019, 5, 30, 15, 17, 46, 90000), 'T/T')
# ...
